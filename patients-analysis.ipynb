# %%
import pandas as pd
df= pd.read_csv(C:/Users/DELL/Desktop/HospitalsDataAnalysis/data/patients.csv)df.head()
# Out:
#   Cell In[1], line 2
#     df= pd.read_csv(C:/Users/DELL/Desktop/HospitalsDataAnalysis/data/patients.csv)df.head()
#                      ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
df= pd.read_csv("C:/Users/DELL/Desktop/HospitalsDataAnalysis/data/patients.csv")
df.head()
# Out:
#   patientID  Age Sex  BloodPressure  Cholesterol         Diagnosis
# 0      P001   45   M            130          220           Healthy
# 1      P002   52   F            150          240  High Cholesterol
# 2      P003   36   M            120          190           Healthy
# 3      P004   60   F            160          260      Hypertension
# 4      P005   48   M            140          250           At Risk

# %%
df.describe()
df['Sex'].value_counts()
df['Diagnosis'].values_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8108\3255183128.py in ?()
# ----> 3 df.describe()
#       4 df['Sex'].value_counts()
#       5 df['Diagnosis'].values_counts()
#
# ~\anaconda3\envs\hosp_env\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'values_counts'

# %%
df.describe()
df['Sex'].value_counts()
df['Diagnosis'].value_counts()
# Out:
# Diagnosis
# Healthy             2
# High Cholesterol    1
# Hypertension        1
# At Risk             1
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.plot(df["Age"], df["Cholesterol"], marker="0")
plt.xlabel("Age")
plt.ylabel("Cholesterol")
plt.title("Cholesterol vs Age")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\envs\hosp_env\lib\site-packages\matplotlib\markers.py:326, in MarkerStyle._set_marker(self, marker)
#     325 try:
# --> 326     Path(marker)
#     327     self._marker_function = self._set_vertices
#
# File ~\anaconda3\envs\hosp_env\lib\site-packages\matplotlib\path.py:130, in Path.__init__(self, vertices, codes, _interpolation_steps, closed, readonly)
#     129 vertices = _to_unmasked_float_array(vertices)
# --> 130 _api.check_shape((None, 2), vertices=vertices)
#     132 if codes is not None:
#
# File ~\anaconda3\envs\hosp_env\lib\site-packages\matplotlib\_api\__init__.py:161, in check_shape(shape, **kwargs)
#     159     text_shape += ","
# --> 161 raise ValueError(
#     162     f"{k!r} must be {len(shape)}D with shape ({text_shape}), "
#     163     f"but your input has shape {v.shape}"
#     164 )
#
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(df["Age"], df["Cholesterol"], marker="o")
plt.xlabel("Age")
plt.ylabel("Cholesterol")
plt.title("Cholesterol vs Age")
plt.show()
